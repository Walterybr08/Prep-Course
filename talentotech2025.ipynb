# %% [markdown]
# <a href="https://colab.research.google.com/github/Walterybr08/Prep-Course/blob/main/talentotech2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#print (2)
#print ("hola Mundo")
#nombre = "Walter"
numero1 = 10
numero2 = 8
numero3 = 2
print ("El resultado es:")
(numero1 + numero2)
print (numero2 + numero3)
# Out:
# El resultado es:
# 10
